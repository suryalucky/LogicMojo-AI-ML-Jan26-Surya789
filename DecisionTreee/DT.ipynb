# %%
import pandas as pd
import numpy as np

# %%
for i in range(1, 6):
    for j in range(1, 6):
        print(i * j, end="\t")   # \t = tab space
    print()
# Out:
# 1	2	3	4	5
# 2	4	6	8	10
# 3	6	9	12	15
# 4	8	12	16	20
# 5	10	15	20	25

# %%
squares = {}
for i in range(1, 6):
    squares[i] = i * i
print(squares)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
