# %%
a = 5
a = 5.5
a = "Hello World"
a = True

# %%
x = 10
print("Type of X:", x, type(x))
# Out:
# Type of X: 10 <class 'int'>

# %% [markdown]
# ## Operators & Comparisons

# %%
import math

print("The floor value of 5.7 is:", math.floor(5.7))
print("The ceiling value of 1.3 is:", math.ceil(1.3))
# Out:
# The floor value of 5.7 is: 5
# The ceiling value of 1.3 is: 2

# %%
a = [1, 2, 3, 4, 5]
b = a.copy()
a is b
# Out:
# False

# %%
a = [1, 2, 3, 4, 5]
b = [1, 2, 3, 4, 5]
a is b
# Out:
# False

# %%
a = [1, 2, 3, 4, 5]
b = a
a is b
# Out:
# True

# %%
a = 10
b = 20
a, b = b, a
print(a, b)
# Out:
# 20 10

# %%
input_Text = " Machine Learning  "
print(input_Text.strip().lower())
# Out:
# machine learning

# %%
input_Text[::-1]
# Out:
# '  gninraeL enihcaM '

# %%
Text = "Machine Learning"
print(Text)
Text.replace(" ", "-")
# Out:
# Machine Learning
# 'Machine-Learning'

# %%
Text.split()
# Out:
# ['Machine', 'Learning']

# %%
split_Text = "Maching,Learning"
split_Text.split(",")
# Out:
# ['Maching', 'Learning']

# %%
word = ["Surya", "Jyothi", "Rajkumar"]
"-".join(word)
# Out:
# 'Surya-Jyothi-Rajkumar'

# %%
", ".join(word)
# Out:
# 'Surya, Jyothi, Rajkumar'

# %%
Name = "Surya"
Age = 25
print(f"My name is {Name} and I am {Age} Years old.")
# Out:
# My name is Surya and I am 25 Years old.

# %%
##deciaml places in f sting
pi = 3.141592653589793
print(f"Value of pi up to 3 decimal places: {pi:.3f}")
print(f"Value of pi up to 5 decimal places: {pi:.5f}")
# Out:
# Value of pi up to 3 decimal places: 3.142
# Value of pi up to 5 decimal places: 3.14159

# %%
List_numbers = [34, 1, 23, 4, 3, 45, 67, 32]
print(f"List numbers:", List_numbers[0], List_numbers[3], List_numbers[0:5], List_numbers[0:7:2], List_numbers[::-1])
# Out:
# List numbers: 34 4 [34, 1, 23, 4, 3] [34, 23, 3, 67] [32, 67, 45, 3, 4, 23, 1, 34]

# %%
Num = [1, 2, 3, 5, 4, 6, 7, 8, 9, 10]
Num2 = [11, 12, 13]
Num.pop()
Num.remove(2)
print(Num)
Num.insert(2, 15)
print(Num)
Num.extend(Num2)
print(Num)
# Out:
# [1, 3, 4, 5, 6, 7, 8, 9]
# [1, 3, 15, 4, 5, 6, 7, 8, 9]
# [1, 3, 15, 4, 5, 6, 7, 8, 9, 11, 12, 13]

# %%
Num2 = [1, 4, 5, 2, 8, 10, 15, 11, 13, 12]
Num2.sort()
print(Num2)
# Out:
# [1, 2, 4, 5, 8, 10, 11, 12, 13, 15]

# %%
Num3 = [1, 4, 5, 2, 8, 10, 15, 11, 13, 12]
Numbersroting = sorted(Num3)
print(f"Original List:", Num3)
print(f"Sorted List:", Numbersroting)
# Out:
# Original List: [1, 4, 5, 2, 8, 10, 15, 11, 13, 12]
# Sorted List: [1, 2, 4, 5, 8, 10, 11, 12, 13, 15]

# %%
for i in Num3:
    print(i * 20)
# Out:
# 20
# 80
# 100
# 40
# 160
# 200
# 300
# 220
# 260
# 240

# %%
0%2
# Out:
# 0
