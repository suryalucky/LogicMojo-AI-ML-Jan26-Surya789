# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------------ --------------------------- 3.1/9.9 MB 22.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 28.6 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    -------------------------- ------------- 8.4/12.4 MB 39.9 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 37.5 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/3 [tzdata]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
#    ------------- -------------------------- 1/3 [numpy]
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

price_series = pd.Series([100, 200, 300, 400, 500], index=['A', 'B', 'c', 'D', 'E'])
print(price_series)
# Out:
# A    100
# B    200
# c    300
# D    400
# E    500
# dtype: int64

# %%
price_series = pd.Series([100, 200, 300, 400, 500], index=['A', 'B', 'C', 'D', 'E'], name = 'Surya')
print(price_series)
# Out:
# A    100
# B    200
# C    300
# D    400
# E    500
# Name: Surya, dtype: int64

# %%
print(f"mean of the series:{price_series.mean()}")
# Out:
# mean of the series:300.0

# %%
print(f"Most expensive item:{price_series.idxmax()} with price {price_series.max()}")
# Out:
# Most expensive item:E with price 500

# %%
Product_data = {
    'Product_ID': [101, 102, 103, 104],
    'Product_Name': ['Laptop', 'Smartphone', 'Tablet', 'Monitor'],
    'Price': [800, 600, 300, 400],
    'Stock': [50, 100, 150, 75]
}

product_df = pd.DataFrame(Product_data)
print(product_df)
# Out:
#    Product_ID Product_Name  Price  Stock
# 0         101       Laptop    800     50
# 1         102   Smartphone    600    100
# 2         103       Tablet    300    150
# 3         104      Monitor    400     75

# %%
print(product_df.shape)
print(list(product_df.columns))
# Out:
# (4, 4)
# ['Product_ID', 'Product_Name', 'Price', 'Stock']

# %%
np.random.seed(42)
n_per_class = 50

setosa = pd.DataFrame({
    'sepal_length': np.random.normal(5.0, 0.35, n_per_class),  ## using this mean and std dev generate 50 random values for each column
    'sepal_width': np.random.normal(3.4, 0.38, n_per_class),
    'petal_length': np.random.normal(1.5, 0.17, n_per_class),
    'petal_width': np.random.normal(0.25, 0.11, n_per_class),
    'species': 'setosa',
    'color': 'white'
})

# Versicolor (medium flowers)

versicolor = pd.DataFrame({
    'sepal_length': np.random.normal(5.9, 0.52, n_per_class),
    'sepal_width': np.random.normal(2.8, 0.31, n_per_class),
    'petal_length': np.random.normal(4.3, 0.47, n_per_class),
    'petal_width': np.random.normal(1.3, 0.20, n_per_class),
    'species': 'versicolor',
    'color' : 'red'
})

# Virginica (larger flowers)

virginica = pd.DataFrame({
    'sepal_length': np.random.normal(6.6, 0.64, n_per_class),
    'sepal_width': np.random.normal(3.0, 0.32, n_per_class),
    'petal_length': np.random.normal(5.5, 0.55, n_per_class),
    'petal_width': np.random.normal(2.0, 0.27, n_per_class),
    'species': 'virginica',
    'color' : 'black'
})

 

# Combine all

df_iris = pd.concat([setosa, versicolor, virginica], ignore_index=True)
print(df_iris)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  color
# 0        5.173850     3.523152      1.259387     0.277554     setosa  white
# 1        4.951607     3.253669      1.428490     0.288109     setosa  white
# 2        5.226691     3.142770      1.441739     0.175197     setosa  white
# 3        5.533060     3.632437      1.363613     0.275548     setosa  white
# 4        4.918046     3.791780      1.472581     0.282238     setosa  white
# ..            ...          ...           ...          ...        ...    ...
# 145      7.028590     3.172451      5.061708     1.862296  virginica  black
# 146      6.834623     2.668081      5.817390     1.927134  virginica  black
# 147      5.998477     2.939092      5.388325     1.735734  virginica  black
# 148      6.271125     2.719802      5.704130     1.880041  virginica  black
# 149      5.922103     2.557504      5.167808     2.101871  virginica  black
#
# [150 rows x 6 columns]

# %%
df_iris.shape
# Out:
# (150, 5)

# %%
df_iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='str')

# %%
df_iris.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0      5.173850     3.523152      1.259387     0.277554  setosa
# 1      4.951607     3.253669      1.428490     0.288109  setosa
# 2      5.226691     3.142770      1.441739     0.175197  setosa
# 3      5.533060     3.632437      1.363613     0.275548  setosa
# 4      4.918046     3.791780      1.472581     0.282238  setosa
# 5      4.918052     3.753886      1.568689     0.171421  setosa
# 6      5.552724     3.081097      1.820652     0.455235  setosa
# 7      5.268602     3.282499      1.529678     0.302122  setosa
# 8      4.835684     3.525880      1.543784     0.118957  setosa
# 9      5.189896     3.770707      1.487344     0.322221  setosa

# %%
df_iris.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 140      6.845802     2.997449      5.959631     2.019323  virginica
# 141      6.579075     3.473582      4.878661     1.871032  virginica
# 142      5.276837     3.024758      5.791392     2.129325  virginica
# 143      6.542963     2.724389      6.292863     2.090089  virginica
# 144      5.765140     3.487400      4.140596     2.280136  virginica
# 145      7.028590     3.172451      5.061708     1.862296  virginica
# 146      6.834623     2.668081      5.817390     1.927134  virginica
# 147      5.998477     2.939092      5.388325     1.735734  virginica
# 148      6.271125     2.719802      5.704130     1.880041  virginica
# 149      5.922103     2.557504      5.167808     2.101871  virginica

# %%
df_iris.describe() #Stastical analysis
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.822797     3.059982      3.722070     1.201029
# std        0.873636     0.421850      1.678461     0.747487
# min        4.314115     1.795207      1.173809     0.083367
# 25%        5.075998     2.747947      1.591489     0.319673
# 50%        5.731060     3.046062      4.292210     1.324807
# 75%        6.446149     3.351060      5.038926     1.879024
# max        7.918879     3.994565      6.550179     2.613087

# %%
df_iris.info() #important for null and data type check
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB

# %%
print("unique value from the data table")

for col in df_iris.columns:
    #unique_value = len(set(df_iris[col]))
    unique_value = df_iris[col].nunique()
    print(f"{col}{unique_value}")
# Out:
# unique value from the data table
# sepal_length150
# sepal_width150
# petal_length150
# petal_width150
# species3

# %%
df_iris[col].unique()
# Out:
# <StringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str

# %%
# Get all the sepal length value that are > 6.5
#df_iris["petal_length"] > 6.5 # in pandas internally loop will happen
df_iris[df_iris["petal_length"] > 6.5] # to get the values we need to use square brackets
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 101        6.2164     3.305646      6.550179     1.957967  virginica

# %%
df_iris[df_iris["petal_width"] < 1][["petal_width", "petal_length"]] # we need to put duble bracket when we need to access multiple columns
# Out:
#     petal_width  petal_length
# 0      0.277554      1.259387
# 1      0.288109      1.428490
# 2      0.175197      1.441739
# 3      0.275548      1.363613
# 4      0.282238      1.472581
# 5      0.171421      1.568689
# 6      0.455235      1.820652
# 7      0.302122      1.529678
# 8      0.118957      1.543784
# 9      0.322221      1.487344
# 10     0.142785      1.173809
# 11     0.336579      1.495493
# 12     0.377446      1.510239
# 13     0.159725      1.918751
# 14     0.355971      1.467299
# 15     0.295406      1.551263
# 16     0.340427      1.494099
# 17     0.458647      1.301325
# 18     0.223007      1.694280
# 19     0.167089      1.627829
# 20     0.152153      1.634475
# 21     0.160261      1.345404
# 22     0.241519      1.738475
# 23     0.287527      1.261685
# 24     0.280436      1.599766
# 25     0.340990      1.872377
# 26     0.251430      1.331609
# 27     0.409889      1.403729
# 28     0.220888      1.516941
# 29     0.549219      1.414409
# ...

# %%
df_iris[(df_iris["sepal_length"] > 6) & (df_iris["petal_length"] > 5)]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 101      6.216400     3.305646      6.550179     1.957967  virginica
# 103      6.630068     3.161295      5.809633     2.068694  virginica
# 104      6.311958     2.830318      5.142147     2.091153  virginica
# 105      6.998624     2.746281      5.232081     1.888793  virginica
# 107      6.508877     2.668722      5.024805     1.883209  virginica
# 108      6.676989     2.822832      5.526687     2.106502  virginica
# 109      6.929241     2.616679      5.042977     1.886334  virginica
# 110      7.055434     3.628712      5.648751     2.078239  virginica
# 113      7.417713     3.068474      5.000840     1.911974  virginica
# 114      6.812681     2.964055      5.182776     2.324328  virginica
# 115      6.120969     2.929290      5.915465     1.889820  virginica
# 116      7.592737     3.196533      5.775504     1.449706  virginica
# 118      7.354750     2.830240      5.554633     1.494886  virginica
# ...

# %%
df_iris[(df_iris["petal_length"] > 2) | (df_iris["petal_width"] > 3)]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 50       6.086049     2.409126      3.910372     1.362182  versicolor
# 51       6.191608     3.084537      4.036715     1.595071  versicolor
# 52       6.463187     3.457868      4.651228     1.471532  versicolor
# 53       6.447977     3.120064      4.586874     1.268012  versicolor
# 54       5.183612     2.328995      4.290176     1.296197  versicolor
# ..            ...          ...           ...          ...         ...
# 145      7.028590     3.172451      5.061708     1.862296   virginica
# 146      6.834623     2.668081      5.817390     1.927134   virginica
# 147      5.998477     2.939092      5.388325     1.735734   virginica
# 148      6.271125     2.719802      5.704130     1.880041   virginica
# 149      5.922103     2.557504      5.167808     2.101871   virginica
#
# [100 rows x 5 columns]

# %%
df_iris[df_iris["species"].isin(["versicolor"])]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species color  \
# 50      6.086049     2.409126      3.910372     1.362182  versicolor   red
# 51      6.191608     3.084537      4.036715     1.595071  versicolor   red
# 52      6.463187     3.457868      4.651228     1.471532  versicolor   red
# 53      6.447977     3.120064      4.586874     1.268012  versicolor   red
# 54      5.183612     2.328995      4.290176     1.296197  versicolor   red
# 55      5.412331     2.649887      4.355144     1.099494  versicolor   red
# 56      6.167818     3.192742      4.900503     1.296297  versicolor   red
# 57      6.167169     2.580622      4.021961     1.242268  versicolor   red
# 58      6.167825     2.937584      4.557136     1.364544  versicolor   red
# 59      7.903420     3.040137      4.204969     1.134554  versicolor   red
# 60      6.196863     2.512652      4.197690     1.403869  versicolor   red
# ...

# %%
df_iris.groupby("species")["petal_length"].mean()
# Out:
# species
# setosa        1.493321
# versicolor    4.315125
# virginica     5.357765
# Name: petal_length, dtype: float64

# %%
df_iris.groupby("species")[["petal_length", "sepal_length", "petal_width", "salary"]].mean()
# Out:
#             petal_length  sepal_length  petal_width  salary
# species
# setosa          1.493321      4.921084     0.259229  2000.0
# versicolor      4.315125      5.978504     1.336300  2000.0
# virginica       5.357765      6.568804     2.007559  2000.0

# %%
#Named aggregations
df_iris.groupby("species").agg(
    avg_petal_len = ("petal_length", "mean"),
    count_sepal_len = ("sepal_length", "count")
)
# Out:
#             avg_petal_len  count_sepal_len
# species
# setosa           1.493321               50
# versicolor       4.315125               50
# virginica        5.357765               50

# %%
#Multicolumn grouping

df_iris.groupby(["species", "color"]).agg(
    avg_petal_len = ("petal_length", "mean"),
    count_sepal_len = ("sepal_length", "count")
)
# Out:
#                   avg_petal_len  count_sepal_len
# species    color
# setosa     white       1.493321               50
# versicolor red         4.315125               50
# virginica  black       5.357765               50

# %%
df_iris.groupby(["species", "color"])["petal_length"].mean()
# Out:
# species     color
# setosa      white    1.493321
# versicolor  red      4.315125
# virginica   black    5.357765
# Name: petal_length, dtype: float64

# %%
##Static Value column
df_iris["salary"] = 2000
df_iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  color  \
# 0        5.173850     3.523152      1.259387     0.277554     setosa  white
# 1        4.951607     3.253669      1.428490     0.288109     setosa  white
# 2        5.226691     3.142770      1.441739     0.175197     setosa  white
# 3        5.533060     3.632437      1.363613     0.275548     setosa  white
# 4        4.918046     3.791780      1.472581     0.282238     setosa  white
# ..            ...          ...           ...          ...        ...    ...
# 145      7.028590     3.172451      5.061708     1.862296  virginica  black
# 146      6.834623     2.668081      5.817390     1.927134  virginica  black
# 147      5.998477     2.939092      5.388325     1.735734  virginica  black
# 148      6.271125     2.719802      5.704130     1.880041  virginica  black
# 149      5.922103     2.557504      5.167808     2.101871  virginica  black
#
#      salary
# 0      2000
# 1      2000
# 2      2000
# ...

# %%
np.random.seed(42)
n_wines = 200

df_wine = pd.DataFrame({
# pd.DataFrame: Creates a 2D labeled data structure (like a table/spreadsheet)
    'alcohol': np.random.uniform(8, 15, n_wines),
    # np.random: NumPy random number generation functions
    'acidity': np.random.uniform(2.5, 4.0, n_wines),
    # np.random: NumPy random number generation functions
    'pH': np.random.uniform(2.8, 3.8, n_wines),
    # np.random: NumPy random number generation functions
    'density': np.random.uniform(0.99, 1.00, n_wines),
    # np.random: NumPy random number generation functions
    'sulphates': np.random.uniform(0.3, 1.5, n_wines),
    # np.random: NumPy random number generation functions
    'residual_sugar': np.random.uniform(1, 15, n_wines),
    # np.random: NumPy random number generation functions
})

df_wine
# Out:
#        alcohol   acidity        pH   density  sulphates  residual_sugar
# 0    10.621781  3.463047  2.903124  0.991689   1.148686        3.591861
# 1    14.655000  2.626210  3.702553  0.992786   0.483047        8.586613
# 2    13.123958  2.742443  3.305252  0.991770   0.991546       13.221242
# 3    12.190609  3.847831  3.626457  0.990887   1.028058       11.251148
# 4     9.092130  3.409644  3.120050  0.991206   0.808957       12.291856
# ..         ...       ...       ...       ...        ...             ...
# 195  10.444467  3.896136  3.273962  0.998721   0.409898       13.201515
# 196  13.081690  3.787619  3.467558  0.999321   1.400776       14.628846
# 197  14.279772  3.143491  2.972320  0.995651   0.464182       14.564290
# 198  14.209605  3.626307  2.992289  0.996967   1.440285       11.495126
# 199  13.459129  3.631814  2.840869  0.999225   0.835207        2.821207
#
# [200 rows x 6 columns]

# %%
df_wine['quality'] = (
    (df_wine['alcohol'] * 0.5) + 
    (df_wine['sulphates'] * 2) - 
    (df_wine['acidity'] * 0.5) + 
    np.random.normal(0, 1, n_wines))

df_wine
# Out:
#        alcohol   acidity        pH   density  sulphates  residual_sugar  \
# 0    10.621781  3.463047  2.903124  0.991689   1.148686        3.591861
# 1    14.655000  2.626210  3.702553  0.992786   0.483047        8.586613
# 2    13.123958  2.742443  3.305252  0.991770   0.991546       13.221242
# 3    12.190609  3.847831  3.626457  0.990887   1.028058       11.251148
# 4     9.092130  3.409644  3.120050  0.991206   0.808957       12.291856
# ..         ...       ...       ...       ...        ...             ...
# 195  10.444467  3.896136  3.273962  0.998721   0.409898       13.201515
# 196  13.081690  3.787619  3.467558  0.999321   1.400776       14.628846
# 197  14.279772  3.143491  2.972320  0.995651   0.464182       14.564290
# 198  14.209605  3.626307  2.992289  0.996967   1.440285       11.495126
# 199  13.459129  3.631814  2.840869  0.999225   0.835207        2.821207
#
#       quality
# 0    5.812601
# 1    7.309251
# 2    7.495207
# 3    6.649426
# 4    6.072868
# ...

# %%
df_wine["wine_type"] = np.random.choice(["Red", "Blue", "Black"], n_wines, p=[0.5, 0.4, 0.1])
df_wine
# Out:
#        alcohol   acidity        pH   density  sulphates  residual_sugar  \
# 0    10.621781  3.463047  2.903124  0.991689   1.148686        3.591861
# 1    14.655000  2.626210  3.702553  0.992786   0.483047        8.586613
# 2    13.123958  2.742443  3.305252  0.991770   0.991546       13.221242
# 3    12.190609  3.847831  3.626457  0.990887   1.028058       11.251148
# 4     9.092130  3.409644  3.120050  0.991206   0.808957       12.291856
# ..         ...       ...       ...       ...        ...             ...
# 195  10.444467  3.896136  3.273962  0.998721   0.409898       13.201515
# 196  13.081690  3.787619  3.467558  0.999321   1.400776       14.628846
# 197  14.279772  3.143491  2.972320  0.995651   0.464182       14.564290
# 198  14.209605  3.626307  2.992289  0.996967   1.440285       11.495126
# 199  13.459129  3.631814  2.840869  0.999225   0.835207        2.821207
#
#       quality wine_type
# 0    5.812601       Red
# 1    7.309251      Blue
# 2    7.495207       Red
# ...

# %%
df_wine.shape
# Out:
# (200, 8)

# %%
df_wine.columns
# Out:
# Index(['alcohol', 'acidity', 'pH', 'density', 'sulphates', 'residual_sugar',
#        'quality', 'wine_type'],
#       dtype='str')

# %%
len(df_wine[df_wine["wine_type"]=="Black"])
# Out:
# 21

# %%
df_wine["wine_type"].value_counts()
# Out:
# wine_type
# Red      105
# Blue      74
# Black     21
# Name: count, dtype: int64

# %%
df_wine
# Out:
#        alcohol   acidity        pH   density  sulphates  residual_sugar  \
# 0    10.621781  3.463047  2.903124  0.991689   1.148686        3.591861
# 1    14.655000  2.626210  3.702553  0.992786   0.483047        8.586613
# 2    13.123958  2.742443  3.305252  0.991770   0.991546       13.221242
# 3    12.190609  3.847831  3.626457  0.990887   1.028058       11.251148
# 4     9.092130  3.409644  3.120050  0.991206   0.808957       12.291856
# ..         ...       ...       ...       ...        ...             ...
# 195  10.444467  3.896136  3.273962  0.998721   0.409898       13.201515
# 196  13.081690  3.787619  3.467558  0.999321   1.400776       14.628846
# 197  14.279772  3.143491  2.972320  0.995651   0.464182       14.564290
# 198  14.209605  3.626307  2.992289  0.996967   1.440285       11.495126
# 199  13.459129  3.631814  2.840869  0.999225   0.835207        2.821207
#
#       quality wine_type
# 0    5.812601       Red
# 1    7.309251      Blue
# 2    7.495207       Red
# ...

# %%
df_wine.select_dtypes(include = [np.number]).corr()["quality"].sort_values(ascending=False)
# Out:
# quality           1.000000
# alcohol           0.584270
# sulphates         0.511358
# residual_sugar    0.015148
# pH               -0.016436
# density          -0.063522
# acidity          -0.219804
# Name: quality, dtype: float64
